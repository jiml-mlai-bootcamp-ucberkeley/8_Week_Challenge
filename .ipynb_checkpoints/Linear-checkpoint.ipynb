# %%
from warnings import filterwarnings
filterwarnings("ignore")

import sys
sys.path.append('common')

from print_more_stuff import print_more_stuff
from regression_models import dosomething
from pprint import pprint
from preprocessing import mean_and_std

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
outliers_df = pd.read_csv('outliers.csv')
outliers_df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
outliers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20480 entries, 0 to 20479
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bed             20480 non-null  float64
#  1   bath            20480 non-null  float64
#  2   acre_lot        20480 non-null  float64
#  3   zip_code        20480 non-null  float64
#  4   house_size      20480 non-null  float64
#  5   price           20480 non-null  float64
#  6   prev_sold_year  20480 non-null  float64
#  7   latitude        20480 non-null  float64
#  8   longitude       20480 non-null  float64
#  9   county          20480 non-null  int64
# dtypes: float64(9), int64(1)
# memory usage: 1.6 MB

# %%
switches = {
    "which_df":"outliers",
    "normalize":False
}
# False True onezipcode onecounty outliers

# %%
groupby_zipcode = outliers_df.groupby(["zip_code"])["zip_code"].count().sort_values(ascending=False)
groupby_zipcode_df = pd.DataFrame(groupby_zipcode).rename(columns={"zip_code":"count"}).reset_index()
first_zipcode = groupby_zipcode_df.iloc[0]["zip_code"]
first_zipcode
# Out:
# 8527.0

# %%
one_zipcode_df = outliers_df[outliers_df["zip_code"].isin([first_zipcode])]

# %%
one_zipcode_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269 entries, 10338 to 10606
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bed             269 non-null    float64
#  1   bath            269 non-null    float64
#  2   acre_lot        269 non-null    float64
#  3   zip_code        269 non-null    float64
#  4   house_size      269 non-null    float64
#  5   price           269 non-null    float64
#  6   prev_sold_year  269 non-null    float64
#  7   latitude        269 non-null    float64
#  8   longitude       269 non-null    float64
#  9   county          269 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 23.1 KB

# %%
groupby_county = outliers_df.groupby(["county"])["county"].count().sort_values(ascending=False)
groupby_county_df = pd.DataFrame(groupby_county).rename(columns={"county":"count"}).reset_index()
first_county = groupby_county_df.iloc[0]["county"]
first_county
# Out:
# 16

# %%
one_county_df = outliers_df[outliers_df["county"].isin([first_county])]

# %%
one_county_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1721 entries, 13052 to 19278
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bed             1721 non-null   float64
#  1   bath            1721 non-null   float64
#  2   acre_lot        1721 non-null   float64
#  3   zip_code        1721 non-null   float64
#  4   house_size      1721 non-null   float64
#  5   price           1721 non-null   float64
#  6   prev_sold_year  1721 non-null   float64
#  7   latitude        1721 non-null   float64
#  8   longitude       1721 non-null   float64
#  9   county          1721 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 147.9 KB

# %%
which_dataframe = outliers_df
match switches["which_df"]:
    case "onezipcode":
        which_dataframe = one_zipcode_df
    case "onecounty":
        which_dataframe = one_county_df
    case _:
        which_dataframe = outliers_df

# %%
normalize_df = which_dataframe

params = {
    "data":which_dataframe,
    "features_a":["prev_sold_year","zip_code","latitude","longitude","county"],
    "features_n":["bed","bath","acre_lot","house_size","price"]
}

match switches["normalize"]:
    case True:
        normalize_df = mean_and_std(params)

normalize_df.tail()
# Out:
#        bed  bath  acre_lot  zip_code  house_size     price  prev_sold_year  \
# 20475  4.0   3.0      0.94    8886.0      1500.0  579000.0          2019.0
# 20476  3.0   3.0      0.11    8886.0      1500.0  356000.0          2006.0
# 20477  3.0   2.0      0.23    8886.0      1500.0   69800.0          2021.0
# 20478  4.0   3.0      0.31    8886.0      1500.0  459000.0          2009.0
# 20479  3.0   2.0      0.14    8886.0      1500.0   79900.0          2020.0
#
#         latitude  longitude  county
# 20475  40.687502 -75.101127      19
# 20476  40.687502 -75.101127      19
# 20477  40.687502 -75.101127      19
# 20478  40.687502 -75.101127      19
# 20479  40.687502 -75.101127      19

# %%
correlation = normalize_df[["zip_code","latitude","longitude","county","acre_lot","bed","bath","house_size","prev_sold_year","price"]].corr()
correlation["price"]
# Out:
# zip_code         -0.116042
# latitude          0.118985
# longitude         0.270237
# county           -0.024563
# acre_lot          0.013009
# bed               0.453542
# bath              0.618459
# house_size        0.361332
# prev_sold_year    0.031241
# price             1.000000
# Name: price, dtype: float64

# %%
sns.heatmap(correlation, vmin=-1, vmax=1, cmap = 'coolwarm', annot=True, fmt='.2f', linewidths=0.1)
plt.title("Correlation Between Variables", pad=20)
# Out:
# Text(0.5, 1.0, 'Correlation Between Variables')

# %%
corrfeatures = ["latitude","longitude"]

match switches["which_df"]:
    case "onezipcode":
        corrfeatures = ["zip_code"]
    case "onecounty":
        corrfeatures = ["county"]
    case _:
        corrfeatures = ["latitude","longitude"]

for feature, value in correlation["price"].items():
    if abs(value) < 0.81 and abs(value) >= 0.17:
        corrfeatures.append(feature)
        
savefeatures = list(dict.fromkeys(corrfeatures))
print(savefeatures)
# Out:
# ['latitude', 'longitude', 'bed', 'bath', 'house_size']

# %%
pariplot_features = []
for feature, value in correlation["price"].items():
        pariplot_features.append(feature)

# %%
features = savefeatures
num_features_to_select = len(features)-1
random_state_value = 42

# %%
X = normalize_df[features]
y = normalize_df["price"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state_value)

# %%
lgr = LinearRegression(fit_intercept=False)
lgr_gscv = GridSearchCV(lgr, param_grid={})
lgr_model = lgr_gscv.fit(X_train,y_train)
lgr_predictions = lgr_model.predict(X_test)

# %%
results_dict = {"model":[], "explained variance score":[],"mae score":[],"mse score":[],"r2 score":[], "mean fit time":[]}

# %%
def results_dict_append(rtnval):
    results_dict["model"].append(rtnval["model"])
    results_dict["explained variance score"].append(rtnval["explained variance score"])
    results_dict["mae score"].append(rtnval["mae score"])
    results_dict["mse score"].append(rtnval["mse score"])
    results_dict["r2 score"].append(rtnval["r2 score"])
    results_dict["mean fit time"].append(rtnval["mean fit time"])

# %%
pms_config = {
    "title":"Linear", 
    "y_param":y_test, 
    "predictions":lgr_predictions, 
    "gscv":lgr_gscv
}

# %%
results = print_more_stuff(pms_config)
# Out:
# Linear EVS = 0.398628748
# Linear MSE = 108,288,728,535.588120
# Linear MAE = 206,996.841822
# Linear R2 = 0.398467
# Linear Fit Time = 0.0050928592681884766

# %%
results_dict_append(results)

# %%
predict_df = pd.DataFrame(lgr_predictions).reset_index()
predict_df.rename(columns={0: "prediction"},inplace=True)

y_test_df = pd.DataFrame(y_test).reset_index()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.ticklabel_format(style='plain')
ax.yaxis.set_major_formatter('${x:1,.0f}')
ax.xaxis.set_major_formatter(' ')

plt.scatter(y_test_df.index,y_test_df["price"], color="red")
plt.scatter(predict_df.index,predict_df["prediction"], color="black")
plt.show()

# %%
results_dict
# Out:
# {'model': ['Linear'],
#  'explained variance score': ['0.398628748'],
#  'mae score': ['206,996.841822'],
#  'mse score': ['108,288,728,535.588120'],
#  'r2 score': ['0.398467'],
#  'mean fit time': [0.0050928592681884766]}

# %%
model_comparisons = pd.DataFrame(results_dict).set_index('model')
model_comparisons
# Out:
#        explained variance score       mae score               mse score  \
# model
# Linear              0.398628748  206,996.841822  108,288,728,535.588120
#
#         r2 score  mean fit time
# model
# Linear  0.398467       0.005093

# %%
not_normlized_features_outliers = {'model': ['Linear'],
 'explained variance score': ['0.398628748'],
 'mae score': ['206,996.841822'],
 'mse score': ['108,288,728,535.588120'],
 'r2 score': ['0.398467'],
 'mean fit time': [0.006371498107910156]}

not_normlized_features_outliers = {'model': ['Linear'],
 'explained variance score': ['0.398133663'],
 'mae score': ['0.496145'],
 'mse score': ['0.622570'],
 'r2 score': ['0.397974'],
 'mean fit time': [0.009705638885498047]}

not_normlized_features_onecounty = {'model': ['Linear'],
 'explained variance score': ['0.356978504'],
 'mae score': ['92,780.083830'],
 'mse score': ['29,231,433,918.020134'],
 'r2 score': ['0.356612'],
 'mean fit time': [0.0050774097442626955]}

normlized_features_onecounty = {'model': ['Linear'],
 'explained variance score': ['0.356978504'],
 'mae score': ['0.444563'],
 'mse score': ['0.671132'],
 'r2 score': ['0.356612'],
 'mean fit time': [0.0048252582550048825]}

not_normlized_features_onezipcode = {'model': ['Linear'],
 'explained variance score': ['0.444986054'],
 'mae score': ['160,153.361798'],
 'mse score': ['90,128,097,153.082581'],
 'r2 score': ['0.424667'],
 'mean fit time': [0.0015189170837402344]}

normlized_features_onezipcode = {'model': ['Linear'],
 'explained variance score': ['0.444986054'],
 'mae score': ['0.512584'],
 'mse score': ['0.923246'],
 'r2 score': ['0.424667'],
 'mean fit time': [0.0016889572143554688]}
