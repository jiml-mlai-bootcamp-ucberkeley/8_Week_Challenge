# %%
from warnings import filterwarnings
filterwarnings("ignore")

import sys
sys.path.append('common')

import datetime
from print_more_stuff import print_more_stuff
from regression_models import dosomething
from pprint import pprint
from preprocessing import mean_and_std

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
outliers_df = pd.read_csv('outliers.csv')
outliers_df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
outliers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20480 entries, 0 to 20479
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bed             20480 non-null  float64
#  1   bath            20480 non-null  float64
#  2   acre_lot        20480 non-null  float64
#  3   zip_code        20480 non-null  float64
#  4   house_size      20480 non-null  float64
#  5   price           20480 non-null  float64
#  6   prev_sold_year  20480 non-null  float64
#  7   latitude        20480 non-null  float64
#  8   longitude       20480 non-null  float64
#  9   county          20480 non-null  int64
# dtypes: float64(9), int64(1)
# memory usage: 1.6 MB

# %%
switches = {
    "which_df":"outliers",
    "normalize":False
}
# False True onezipcode onecounty outliers

# %%
groupby_zipcode = outliers_df.groupby(["zip_code"])["zip_code"].count().sort_values(ascending=False)
groupby_zipcode_df = pd.DataFrame(groupby_zipcode).rename(columns={"zip_code":"count"}).reset_index()
first_zipcode = groupby_zipcode_df.iloc[0]["zip_code"]
first_zipcode
# Out:
# 8527.0

# %%
one_zipcode_df = outliers_df[outliers_df["zip_code"].isin([first_zipcode])]

# %%
one_zipcode_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 269 entries, 10338 to 10606
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bed             269 non-null    float64
#  1   bath            269 non-null    float64
#  2   acre_lot        269 non-null    float64
#  3   zip_code        269 non-null    float64
#  4   house_size      269 non-null    float64
#  5   price           269 non-null    float64
#  6   prev_sold_year  269 non-null    float64
#  7   latitude        269 non-null    float64
#  8   longitude       269 non-null    float64
#  9   county          269 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 23.1 KB

# %%
groupby_county = outliers_df.groupby(["county"])["county"].count().sort_values(ascending=False)
groupby_county_df = pd.DataFrame(groupby_county).rename(columns={"county":"count"}).reset_index()
first_county = groupby_county_df.iloc[0]["county"]
first_county
# Out:
# 16

# %%
one_county_df = outliers_df[outliers_df["county"].isin([first_county])]

# %%
one_county_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1721 entries, 13052 to 19278
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   bed             1721 non-null   float64
#  1   bath            1721 non-null   float64
#  2   acre_lot        1721 non-null   float64
#  3   zip_code        1721 non-null   float64
#  4   house_size      1721 non-null   float64
#  5   price           1721 non-null   float64
#  6   prev_sold_year  1721 non-null   float64
#  7   latitude        1721 non-null   float64
#  8   longitude       1721 non-null   float64
#  9   county          1721 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 147.9 KB

# %%
which_dataframe = outliers_df
match switches["which_df"]:
    case "onezipcode":
        which_dataframe = one_zipcode_df
    case "onecounty":
        which_dataframe = one_county_df
    case _:
        which_dataframe = outliers_df

# %%
normalize_df = which_dataframe

params = {
    "data":which_dataframe,
    "features_a":["prev_sold_year","zip_code","latitude","longitude","county"],
    "features_n":["bed","bath","acre_lot","house_size","price"]
}

match switches["normalize"]:
    case True:
        normalize_df = mean_and_std(params)

normalize_df.tail()
# Out:
#        bed  bath  acre_lot  zip_code  house_size     price  prev_sold_year  \
# 20475  4.0   3.0      0.94    8886.0      1500.0  579000.0          2019.0
# 20476  3.0   3.0      0.11    8886.0      1500.0  356000.0          2006.0
# 20477  3.0   2.0      0.23    8886.0      1500.0   69800.0          2021.0
# 20478  4.0   3.0      0.31    8886.0      1500.0  459000.0          2009.0
# 20479  3.0   2.0      0.14    8886.0      1500.0   79900.0          2020.0
#
#         latitude  longitude  county
# 20475  40.687502 -75.101127      19
# 20476  40.687502 -75.101127      19
# 20477  40.687502 -75.101127      19
# 20478  40.687502 -75.101127      19
# 20479  40.687502 -75.101127      19

# %%
correlation = normalize_df[["zip_code","latitude","longitude","county","acre_lot","bed","bath","house_size","prev_sold_year","price"]].corr()
correlation["price"]
# Out:
# zip_code         -0.116042
# latitude          0.118985
# longitude         0.270237
# county           -0.024563
# acre_lot          0.013009
# bed               0.453542
# bath              0.618459
# house_size        0.361332
# prev_sold_year    0.031241
# price             1.000000
# Name: price, dtype: float64

# %%
sns.heatmap(correlation, vmin=-1, vmax=1, cmap = 'coolwarm', annot=True, fmt='.2f', linewidths=0.1)
plt.title("Correlation Between Variables", pad=20)
# Out:
# Text(0.5, 1.0, 'Correlation Between Variables')

# %%
corrfeatures = ["latitude","longitude"]

match switches["which_df"]:
    case "onezipcode":
        corrfeatures = []
    case "onecounty":
        corrfeatures = []
    case _:
        corrfeatures = ["latitude","longitude"]

for feature, value in correlation["price"].items():
    if abs(value) < 0.81 and abs(value) >= 0.20:
        corrfeatures.append(feature)
        
savefeatures = list(dict.fromkeys(corrfeatures))
print(savefeatures)
# Out:
# ['latitude', 'longitude', 'bed', 'bath', 'house_size']

# %%
pariplot_features = []
for feature, value in correlation["price"].items():
        pariplot_features.append(feature)

# %%
features = savefeatures
num_features_to_select = len(features)-1
random_state_value = 42

# %%
X = normalize_df[features]
y = normalize_df["price"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=random_state_value)

# %%
results_dict = {"dataframe":[],"normalized":[],"timestamp":[],"model":[],
                "explained variance score":[],"mae score":[],"mse score":[],"r2 score":[], "mean fit time":[]}

# %%
def results_dict_append(rtnval):
    results_dict["dataframe"].append(rtnval["dataframe"])   
    results_dict["normalized"].append(rtnval["normalized"])
    results_dict["timestamp"].append(datetime.datetime.now())
    results_dict["model"].append(rtnval["model"])
    results_dict["explained variance score"].append(rtnval["explained variance score"])
    results_dict["mae score"].append(rtnval["mae score"])
    results_dict["mse score"].append(rtnval["mse score"])
    results_dict["r2 score"].append(rtnval["r2 score"])
    results_dict["mean fit time"].append(rtnval["mean fit time"])

# %%
adaboost = AdaBoostRegressor()
adaboost_gscv = GridSearchCV(adaboost, param_grid={})
adaboost_model = adaboost_gscv.fit(X_train,y_train)
adaboost_predictions = adaboost_model.predict(X_test)

# %%
pms_config = {
    "title":"Ada Boost", 
    "y_param":y_test, 
    "predictions":adaboost_predictions, 
    "gscv":adaboost_gscv
}

# %%
results = print_more_stuff(pms_config)
results["dataframe"] = switches["which_df"]
results["normalized"] = switches["normalize"]
# Out:
# Ada Boost EVS = 0.404532524
# Ada Boost MSE = 215,364,044,055.375000
# Ada Boost MAE = 397,872.892212
# Ada Boost R2 = -0.196326
# Ada Boost Fit Time = 0.21005620956420898

# %%
results_dict_append(results)

# %%
grboost = GradientBoostingRegressor()
grboost_gscv = GridSearchCV(grboost, param_grid={})
grboost_model = grboost_gscv.fit(X_train,y_train)
grboost_predictions = grboost_model.predict(X_test)

# %%
pms_config = {
    "title":"Gradient Boost", 
    "y_param":y_test, 
    "predictions":grboost_predictions, 
    "gscv":grboost_gscv
}

# %%
results = print_more_stuff(pms_config)
results["dataframe"] = switches["which_df"]
results["normalized"] = switches["normalize"]
# Out:
# Gradient Boost EVS = 0.641161257
# Gradient Boost MSE = 64,613,637,371.355896
# Gradient Boost MAE = 149,839.271545
# Gradient Boost R2 = 0.641078
# Gradient Boost Fit Time = 0.7782855033874512

# %%
results_dict_append(results)

# %%
histgrboost = HistGradientBoostingRegressor()
histgrboost_gscv = GridSearchCV(histgrboost, param_grid={})
histgrboost_model = histgrboost_gscv.fit(X_train,y_train)
histgrboost_predictions = histgrboost_model.predict(X_test)

# %%
pms_config = {
    "title":"Hist Gradient Boost", 
    "y_param":y_test, 
    "predictions":histgrboost_predictions, 
    "gscv":histgrboost_gscv
}

# %%
results = print_more_stuff(pms_config)
results["dataframe"] = switches["which_df"]
results["normalized"] = switches["normalize"]
# Out:
# Hist Gradient Boost EVS = 0.700999632
# Hist Gradient Boost MSE = 53,830,947,545.332909
# Hist Gradient Boost MAE = 130,241.083766
# Hist Gradient Boost R2 = 0.700975
# Hist Gradient Boost Fit Time = 0.891446590423584

# %%
results_dict_append(results)

# %%
rf = RandomForestRegressor()
rf_gscv = GridSearchCV(rf, param_grid={})
rf_model = rf_gscv.fit(X_train,y_train)
rf_predictions = rf_model.predict(X_test)

# %%
pms_config = {
    "title":"RandomForest", 
    "y_param":y_test, 
    "predictions":rf_predictions, 
    "gscv":rf_gscv
}

# %%
results = print_more_stuff(pms_config)
results["dataframe"] = switches["which_df"]
results["normalized"] = switches["normalize"]
# Out:
# RandomForest EVS = 0.676107028
# RandomForest MSE = 58,307,912,725.122581
# RandomForest MAE = 135,800.623592
# RandomForest R2 = 0.676105
# RandomForest Fit Time = 3.3355611324310304

# %%
results_dict_append(results)

# %%
adaboost_predict_df = pd.DataFrame(adaboost_predictions).reset_index()
adaboost_predict_df.rename(columns={0: "prediction"},inplace=True)

grboost_predict_df = pd.DataFrame(grboost_predictions).reset_index()
grboost_predict_df.rename(columns={0: "prediction"},inplace=True)

rf_predict_df = pd.DataFrame(rf_predictions).reset_index()
rf_predict_df.rename(columns={0: "prediction"},inplace=True)

histgbr_predict_df = pd.DataFrame(histgrboost_predictions).reset_index()
histgbr_predict_df.rename(columns={0: "prediction"},inplace=True)

y_test_df = pd.DataFrame(y_test).reset_index()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.ticklabel_format(style='plain')
ax.yaxis.set_major_formatter('${x:1,.0f}')
ax.xaxis.set_major_formatter(' ')

plt.scatter(y_test_df.index, y_test_df["price"], color="red")
#plt.scatter(adaboost_predict_df.index, adaboost_predict_df["prediction"], color="black")
plt.scatter(grboost_predict_df.index, grboost_predict_df["prediction"], color="blue")
plt.scatter(histgbr_predict_df.index,histgbr_predict_df["prediction"], color="green")
plt.scatter(rf_predict_df.index,rf_predict_df["prediction"], color="black")

plt.show()

# %%
results_dict
# Out:
# {'dataframe': ['outliers', 'outliers', 'outliers', 'outliers'],
#  'normalized': [False, False, False, False],
#  'timestamp': [datetime.datetime(2024, 3, 21, 9, 16, 52, 653821),
#   datetime.datetime(2024, 3, 21, 9, 16, 57, 595692),
#   datetime.datetime(2024, 3, 21, 9, 17, 3, 31239),
#   datetime.datetime(2024, 3, 21, 9, 17, 25, 93675)],
#  'model': ['Ada Boost',
#   'Gradient Boost',
#   'Hist Gradient Boost',
#   'RandomForest'],
#  'explained variance score': ['0.404532524',
#   '0.641161257',
#   '0.700999632',
#   '0.676107028'],
#  'mae score': ['397,872.892212',
#   '149,839.271545',
#   '130,241.083766',
#   '135,800.623592'],
#  'mse score': ['215,364,044,055.375000',
#   '64,613,637,371.355896',
#   '53,830,947,545.332909',
#   '58,307,912,725.122581'],
#  'r2 score': ['-0.196326', '0.641078', '0.700975', '0.676105'],
#  'mean fit time': [0.21005620956420898,
#   0.7782855033874512,
#   0.891446590423584,
#   3.3355611324310304]}

# %%
model_comparisons = pd.DataFrame(results_dict).set_index('model')
model_comparisons
# Out:
#                     dataframe  normalized                  timestamp  \
# model
# Ada Boost            outliers       False 2024-03-21 09:16:52.653821
# Gradient Boost       outliers       False 2024-03-21 09:16:57.595692
# Hist Gradient Boost  outliers       False 2024-03-21 09:17:03.031239
# RandomForest         outliers       False 2024-03-21 09:17:25.093675
#
#                     explained variance score       mae score  \
# model
# Ada Boost                        0.404532524  397,872.892212
# Gradient Boost                   0.641161257  149,839.271545
# Hist Gradient Boost              0.700999632  130,241.083766
# RandomForest                     0.676107028  135,800.623592
#
#                                   mse score   r2 score  mean fit time
# model
# Ada Boost            215,364,044,055.375000  -0.196326       0.210056
# Gradient Boost        64,613,637,371.355896   0.641078       0.778286
# Hist Gradient Boost   53,830,947,545.332909   0.700975       0.891447
# RandomForest          58,307,912,725.122581   0.676105       3.335561

# %%
save_results = [
{'dataframe': ['outliers', 'outliers', 'outliers', 'outliers'],
 'normalized': [True, True, True, True],
 'timestamp': [datetime.datetime(2024, 3, 21, 7, 55, 0, 767591),
  datetime.datetime(2024, 3, 21, 7, 55, 5, 569952),
  datetime.datetime(2024, 3, 21, 7, 55, 9, 358160),
  datetime.datetime(2024, 3, 21, 7, 55, 47, 265138)],
 'model': ['Ada Boost',
  'Gradient Boost',
  'Hist Gradient Boost',
  'RandomForest'],
 'explained variance score': ['0.412703854',
  '0.641161257',
  '0.695441306',
  '0.677029913'],
 'mae score': ['0.845270', '0.359129', '0.315444', '0.324770'],
 'mse score': ['1.036738', '0.371170', '0.314983', '0.333992'],
 'r2 score': ['-0.002527', '0.641078', '0.695411', '0.677030'],
 'mean fit time': [0.1402590274810791,
  0.7095626831054688,
  0.6219364643096924,
  6.38255500793457]},{'dataframe': ['outliers', 'outliers', 'outliers', 'outliers'],
 'normalized': [False, False, False, False],
 'timestamp': [datetime.datetime(2024, 3, 21, 9, 16, 52, 653821),
  datetime.datetime(2024, 3, 21, 9, 16, 57, 595692),
  datetime.datetime(2024, 3, 21, 9, 17, 3, 31239),
  datetime.datetime(2024, 3, 21, 9, 17, 25, 93675)],
 'model': ['Ada Boost',
  'Gradient Boost',
  'Hist Gradient Boost',
  'RandomForest'],
 'explained variance score': ['0.404532524',
  '0.641161257',
  '0.700999632',
  '0.676107028'],
 'mae score': ['397,872.892212',
  '149,839.271545',
  '130,241.083766',
  '135,800.623592'],
 'mse score': ['215,364,044,055.375000',
  '64,613,637,371.355896',
  '53,830,947,545.332909',
  '58,307,912,725.122581'],
 'r2 score': ['-0.196326', '0.641078', '0.700975', '0.676105'],
 'mean fit time': [0.21005620956420898,
  0.7782855033874512,
  0.891446590423584,
  3.3355611324310304]}]

# %%
save_comparisons = []
for result in save_results:
    save_comparisons.append(pd.DataFrame(result))

save_dataframes = pd.concat(save_comparisons).set_index('model')
save_dataframes
# Out:
#                     dataframe  normalized                  timestamp  \
# model
# Ada Boost            outliers        True 2024-03-21 07:55:00.767591
# Gradient Boost       outliers        True 2024-03-21 07:55:05.569952
# Hist Gradient Boost  outliers        True 2024-03-21 07:55:09.358160
# RandomForest         outliers        True 2024-03-21 07:55:47.265138
# Ada Boost            outliers       False 2024-03-21 09:16:52.653821
# Gradient Boost       outliers       False 2024-03-21 09:16:57.595692
# Hist Gradient Boost  outliers       False 2024-03-21 09:17:03.031239
# RandomForest         outliers       False 2024-03-21 09:17:25.093675
#
#                     explained variance score       mae score  \
# model
# Ada Boost                        0.412703854        0.845270
# Gradient Boost                   0.641161257        0.359129
# Hist Gradient Boost              0.695441306        0.315444
# RandomForest                     0.677029913        0.324770
# Ada Boost                        0.404532524  397,872.892212
# Gradient Boost                   0.641161257  149,839.271545
# Hist Gradient Boost              0.700999632  130,241.083766
# RandomForest                     0.676107028  135,800.623592
#
#                                   mse score   r2 score  mean fit time
# model
# Ada Boost                          1.036738  -0.002527       0.140259
# Gradient Boost                     0.371170   0.641078       0.709563
# Hist Gradient Boost                0.314983   0.695411       0.621936
# RandomForest                       0.333992   0.677030       6.382555
# Ada Boost            215,364,044,055.375000  -0.196326       0.210056
# Gradient Boost        64,613,637,371.355896   0.641078       0.778286
# Hist Gradient Boost   53,830,947,545.332909   0.700975       0.891447
# RandomForest          58,307,912,725.122581   0.676105       3.335561
