# %%
from warnings import filterwarnings 
filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.cluster import KMeans

# %% [markdown]
# #### Read the outliers file and add a feature "prev_sold_year"

# %%
realtor_data_df = pd.read_csv('NewJersey-realtor-data.csv')

# %%
realtor_data_df.drop(columns=['Unnamed: 0'],inplace=True)

# %% [markdown]
# #### Create a feature that will append '0' to the zipcode feature

# %%
realtor_data_df.head()
# Out:
#      status  bed  bath  acre_lot        city       state  zip_code  \
# 0  for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 1  for_sale  2.0   2.0      0.11      Avenel  New Jersey    7001.0
# 2  for_sale  3.0   2.0      0.14      Avenel  New Jersey    7001.0
# 3  for_sale  3.0   1.0      0.11      Avenel  New Jersey    7001.0
# 4  for_sale  NaN   NaN      0.11      Avenel  New Jersey    7001.0
#
#    house_size prev_sold_date     price  prev_sold_year
# 0      1500.0            NaN  333490.0             NaN
# 1      1456.0     1987-05-20  339900.0          1987.0
# 2      1542.0     2022-01-27  305100.0          2022.0
# 3       925.0            NaN  205000.0             NaN
# 4         NaN     2016-12-21  479000.0          2016.0

# %% [markdown]
# #### Get the unique zipcodes in the dataframe

# %%
zipcodes = realtor_data_df["zip_code"]
len(zipcodes.unique())
# Out:
# 583

# %% [markdown]
# #### Read the file with Latitude and Longitude, rename the features

# %%
# Because of its size this dataset is not saved in the code repo for this project.
# It can be downloaded and saved in the same path to make this Notebook run.
zip_lon_lat = pd.read_csv('../../zip_lat_long.csv')
zip_lon_lat.rename(columns={"ZIP":"zip_code", "LAT":"latitude", "LNG":"longitude"},inplace=True)
zip_lon_lat.head()
# Out:
#    zip_code   latitude  longitude
# 0       601  18.180555 -66.749961
# 1       602  18.361945 -67.175597
# 2       603  18.455183 -67.119887
# 3       606  18.158345 -66.932911
# 4       610  18.295366 -67.125135

# %% [markdown]
# #### Find matching zipcodes that were found in the dataset

# %%
find_zipcodes_df = zip_lon_lat[zip_lon_lat["zip_code"].isin(zipcodes.unique())]
find_zipcodes_df.head()
# Out:
#       zip_code   latitude  longitude
# 1974      7001  40.582316 -74.271506
# 1975      7002  40.662338 -74.110275
# 1976      7003  40.809128 -74.187155
# 1977      7004  40.882508 -74.304593
# 1978      7005  40.932771 -74.417304

# %% [markdown]
# #### Merge the dataset with the Latitude and Longitude data

# %%
merge_df = realtor_data_df.merge(find_zipcodes_df, how='outer', on='zip_code')

# %% [markdown]
# #### Display the records that didn't match up

# %%
merge_df[merge_df["latitude"].isna()]
# Out:
#          status  bed  bath  acre_lot             city       state  zip_code  \
# 13197  for_sale  3.0   3.0       NaN       Old Bridge  New Jersey    8557.0
# 13198  for_sale  4.0   3.0      0.31       Old Bridge  New Jersey    8557.0
# 15081  for_sale  4.0   4.0      7.50       Stillwater  New Jersey    7875.0
# 18357  for_sale  NaN   NaN      0.23         Navesink  New Jersey    7752.0
# 19000  for_sale  2.0   2.0      0.01      Perth Amboy  New Jersey    8862.0
# 19249  for_sale  NaN   NaN     45.60             Hope  New Jersey    7844.0
# 19250  for_sale  NaN   NaN     58.40             Hope  New Jersey    7844.0
# 20292  for_sale  2.0   2.0      0.01     Hillsborough  New Jersey    8444.0
# 25618  for_sale  NaN   NaN      9.16      East Amwell  New Jersey    8851.0
# 29778  for_sale  4.0   2.0       NaN         Adelphia  New Jersey    7710.0
# 30536  for_sale  4.0   NaN      0.00         Grenloch  New Jersey    8032.0
# 31980  for_sale  4.0   1.0      0.76           Goshen  New Jersey    8218.0
# 32094  for_sale  4.0   4.0      1.38           Mizpah  New Jersey    8342.0
# 32095  for_sale  3.0   2.0      0.35           Mizpah  New Jersey    8342.0
# 32096  for_sale  NaN   NaN      0.34  Middle Township  New Jersey    8252.0
# 32097  for_sale  NaN   NaN       NaN       Whitesboro  New Jersey    8252.0
# 32098  for_sale  5.0   2.0      1.42      Dennisville  New Jersey    8245.0
# 32212  for_sale  4.0   4.0      0.32       Strathmere  New Jersey    8239.0
# 32530  for_sale  5.0   5.0      0.12   Normandy Beach  New Jersey    8739.0
#
#        house_size prev_sold_date      price  prev_sold_year  latitude  \
# 13197      2184.0            NaN   534900.0             NaN       NaN
# 13198         NaN            NaN   400000.0             NaN       NaN
# 15081         NaN            NaN   899900.0             NaN       NaN
# 18357         NaN            NaN   175000.0             NaN       NaN
# 19000         NaN     2001-02-06   219900.0          2001.0       NaN
# 19249         NaN            NaN   571428.0             NaN       NaN
# 19250         NaN            NaN   795000.0             NaN       NaN
# 20292      1188.0            NaN   275000.0             NaN       NaN
# 25618         NaN            NaN   275000.0             NaN       NaN
# 29778         NaN            NaN   339000.0             NaN       NaN
# 30536      2048.0            NaN   225000.0             NaN       NaN
# 31980      1498.0     2022-06-17   195000.0          2022.0       NaN
# 32094      3360.0            NaN   384000.0             NaN       NaN
# 32095         NaN            NaN   248000.0             NaN       NaN
# 32096         NaN            NaN    19000.0             NaN       NaN
# 32097         NaN            NaN    77100.0             NaN       NaN
# 32098      3073.0     2022-02-25   469900.0          2022.0       NaN
# 32212      2945.0     2022-04-29  2299999.0          2022.0       NaN
# 32530      3192.0            NaN  1749000.0             NaN       NaN
#
#        longitude
# 13197        NaN
# 13198        NaN
# 15081        NaN
# 18357        NaN
# 19000        NaN
# 19249        NaN
# 19250        NaN
# 20292        NaN
# 25618        NaN
# 29778        NaN
# 30536        NaN
# 31980        NaN
# 32094        NaN
# 32095        NaN
# 32096        NaN
# 32097        NaN
# 32098        NaN
# 32212        NaN
# 32530        NaN

# %% [markdown]
# #### Drop the records that didn't match up

# %%
merge_df.dropna(subset=['latitude'], inplace=True)

# %%
merge_df.head()
# Out:
#      status  bed  bath  acre_lot        city       state  zip_code  \
# 0  for_sale  3.0   3.0      0.07  Burlington  New Jersey    8016.0
# 1  for_sale  4.0   2.0      0.26  Burlington  New Jersey    8016.0
# 2  for_sale  3.0   2.0      0.22  Burlington  New Jersey    8016.0
# 3  for_sale  3.0   2.0      0.20  Burlington  New Jersey    8016.0
# 4  for_sale  5.0   2.0      0.05  Burlington  New Jersey    8016.0
#
#    house_size prev_sold_date     price  prev_sold_year   latitude  longitude
# 0      1500.0            NaN  333490.0             NaN  40.069522 -74.824196
# 1      1764.0     2018-07-17  279000.0          2018.0  40.069522 -74.824196
# 2      1988.0     2016-10-24  299000.0          2016.0  40.069522 -74.824196
# 3      1764.0     2020-08-23  275000.0          2020.0  40.069522 -74.824196
# 4      2104.0     2007-01-24  219900.0          2007.0  40.069522 -74.824196

# %% [markdown]
# #### Use KMeans to cluster latitude and longitude into counties

# %%
numberofcounties = 21
kmeans = KMeans(init="random", n_clusters=21,random_state=0)
latlong = merge_df[["latitude","longitude"]]
kmeans.fit(latlong)
y_kmeans = kmeans.predict(latlong)

# %% [markdown]
# #### Plot the counties

# %%
fig, ax = plt.subplots(figsize=(6, 10))
plt.scatter(merge_df["longitude"], merge_df["latitude"], c=y_kmeans, s=50, cmap='viridis')

# %% [markdown]
# #### Add county to the dataset going forward

# %%
merge_df["county"] = np.float64(y_kmeans)

# %%
merge_df.tail()
# Out:
#          status  bed  bath  acre_lot                city       state  \
# 32595  for_sale  NaN   NaN      0.93  Greenwich Township  New Jersey
# 32596  for_sale  NaN   NaN      0.23  Greenwich Township  New Jersey
# 32597  for_sale  NaN   NaN      0.92  Greenwich Township  New Jersey
# 32598  for_sale  4.0   3.0      0.31  Greenwich Township  New Jersey
# 32599  for_sale  NaN   NaN      0.14  Greenwich Township  New Jersey
#
#        zip_code  house_size prev_sold_date     price  prev_sold_year  \
# 32595    8886.0         NaN            NaN  170000.0             NaN
# 32596    8886.0         NaN     2021-02-18   69800.0          2021.0
# 32597    8886.0         NaN            NaN  170000.0             NaN
# 32598    8886.0         NaN     2009-07-31  459000.0          2009.0
# 32599    8886.0         NaN     2020-11-16   79900.0          2020.0
#
#         latitude  longitude  county
# 32595  40.687502 -75.101127    17.0
# 32596  40.687502 -75.101127    17.0
# 32597  40.687502 -75.101127    17.0
# 32598  40.687502 -75.101127    17.0
# 32599  40.687502 -75.101127    17.0

# %% [markdown]
# #### Save the records to a csv file

# %%
merge_df.to_csv("geocoded.csv")
